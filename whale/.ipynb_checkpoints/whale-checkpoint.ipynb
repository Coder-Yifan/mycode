# %%
import pandas as pd

df = pd.read_csv('./train.csv')
# df.groupby('Id')
grouped = df.groupby('Id')

# %%
grouped.groups
# grouped.ngroup()
# grouped.hist
# grouped.count()
# Out:
#            Image
# Id
# new_whale    810
# w_0013924      3
# w_001ebbc      1
# w_002222a      2
# w_002b682      1
# w_002dc11      1
# w_0087fdd      2
# w_008c602      1
# w_009dc00      2
# w_00b621b      2
# w_00c4901      1
# w_00cb685      3
# w_00d8453      1
# w_00fbb4e      2
# w_0103030      1
# w_010a1fa      2
# w_011d4b5      2
# w_0122d85      1
# w_01319fa      1
# w_0134192      1
# w_013bbcf      1
# w_014250a      2
# w_014a645      1
# w_0156f27      1
# w_015c991      1
# w_015e3cf      1
# w_01687a8      2
# w_0175a35      1
# w_018bc64      1
# w_01a4234      1
# ...          ...
# w_fe5e78b      3
# w_fe6617a      2
# w_fe6c1f3      1
# w_fe6f08d      1
# w_fe8233d      1
# w_fe87f0a      2
# w_fe922c3      1
# w_fe95ab8      4
# w_fe96bef      1
# w_fea7fe6      9
# w_feab6f3      1
# w_febafc1      3
# w_fec1fb5      1
# w_fec6413      1
# w_fed0031      2
# w_ff1b64c      5
# w_ff2c4a4      1
# w_ff2ca5c      1
# w_ff39e03      1
# w_ff5538f      1
# ...
