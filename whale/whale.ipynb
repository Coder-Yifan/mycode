# %%
import pandas as pd

df = pd.read_csv('./train.csv')
# df.groupby('Id')
grouped = df.groupby('Id')
grouped.count()
# Out:
#            Image
# Id
# new_whale    810
# w_0013924      3
# w_001ebbc      1
# w_002222a      2
# w_002b682      1
# w_002dc11      1
# w_0087fdd      2
# w_008c602      1
# w_009dc00      2
# w_00b621b      2
# w_00c4901      1
# w_00cb685      3
# w_00d8453      1
# w_00fbb4e      2
# w_0103030      1
# w_010a1fa      2
# w_011d4b5      2
# w_0122d85      1
# w_01319fa      1
# w_0134192      1
# w_013bbcf      1
# w_014250a      2
# w_014a645      1
# w_0156f27      1
# w_015c991      1
# w_015e3cf      1
# w_01687a8      2
# w_0175a35      1
# w_018bc64      1
# w_01a4234      1
# ...          ...
# w_fe5e78b      3
# w_fe6617a      2
# w_fe6c1f3      1
# w_fe6f08d      1
# w_fe8233d      1
# w_fe87f0a      2
# w_fe922c3      1
# w_fe95ab8      4
# w_fe96bef      1
# w_fea7fe6      9
# w_feab6f3      1
# w_febafc1      3
# w_fec1fb5      1
# w_fec6413      1
# w_fed0031      2
# w_ff1b64c      5
# w_ff2c4a4      1
# w_ff2ca5c      1
# w_ff39e03      1
# w_ff5538f      1
# ...

# %%
# grouped.groups
ng = grouped.ngroup()
# grouped.hist


df['class'] = ng
df
# Out:
#              Image         Id  class
# 0     00022e1a.jpg  w_e15442c   3741
# 1     000466c4.jpg  w_1287fbc    310
# 2     00087b01.jpg  w_da2efe0   3613
# 3     001296d5.jpg  w_19e5482    418
# 4     0014cfdf.jpg  w_f22f3e3   4012
# 5     0025e8c2.jpg  w_8b1ca89   2332
# 6     0026a8ab.jpg  w_eaad6a8   3889
# 7     0031c258.jpg  new_whale      0
# 8     0035632e.jpg  w_3d0bc7a    991
# 9     0037e7d3.jpg  w_50db782   1341
# 10    00389cd7.jpg  w_2863d51    651
# 11    0042dcc4.jpg  w_6dc7db6   1811
# 12    0042ea34.jpg  w_968f2ca   2530
# 13    00467ae9.jpg  w_fd1cb9d   4197
# 14    004a97f3.jpg  w_60759c2   1589
# 15    004c5fb9.jpg  w_ab6bb0a   2862
# 16    005c57e7.jpg  w_79b42cd   2030
# 17    006d0aaf.jpg  w_c9ba30c   3336
# 18    0078af23.jpg  w_e6ec8ee   3834
# 19    007c3603.jpg  new_whale      0
# 20    00863b8c.jpg  new_whale      0
# 21    008809b5.jpg  w_7e5cc5e   2104
# 22    008baccf.jpg  w_ab6db0f   2863
# 23    0091c92b.jpg  w_bc8d634   3140
# ...
